# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/model_exp3
# Out:
# /content/drive/MyDrive/model_exp3

# %%
ls
# Out:
# benchmark_vlm.py
# compare_models.py
# config.yaml
# exp_run.ipynb
# finetuning_scripts/
# requirements.txt
# results_before_FT_n_KD_100samples/
# results_qwen_finetuned_spatial_cust_data_lower_than_before/
# run_all.py
# run_model.py
# test_script/
# unsloth_compiled_cache/
# vlm_bench/

# %%
# !hf download OpenGVLab/InternVL2_5-1B

# %%
# !hf auth login
# Out:
# Hint: A new version of huggingface_hub (1.16.4) is available! You are using version 1.16.1.
# To update, run: hf update
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? [y/N]: n
# Token is valid (permission: fineGrained).
# ...

# %%
# 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

# %%
# !pip install -r requirements.txt

# %%
# %%capture
import os, re
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth  # Do this in local & cloud setups
else:
    import torch; v = re.match(r'[\d]{1,}\.[\d]{1,}', str(torch.__version__)).group(0)
    xformers = 'xformers==' + {'2.10':'0.0.34','2.9':'0.0.33.post1','2.8':'0.0.32.post2'}.get(v, "0.0.34")
    # !pip install sentencepiece protobuf "datasets==4.3.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth_zoo bitsandbytes accelerate {xformers} peft trl triton unsloth
    # !pip install --no-deps --upgrade "torchao>=0.16.0"
# !pip install transformers==4.57.1
# !pip install --no-deps trl==0.22.2

# %%
# %run infer_internvl.py

# %%
# from PIL import Image
# img = Image.open("/content/image (5).jpg")
# response = ask_image(img, """How many table lamps are in the image? Select from the following choices.
# (A) 0
# (B) 2
# (C) 1
# (D) 3""")
# print(response)

# %% [markdown]
# # RUN THE EVAL - which model is better? and which one to use as the Knowledge Model

# %%
# !python benchmark_vlm.py --config config.yaml

# %%
# !python run_model.py --config config.yaml --model "InternVL3.5-1B"
# Out:
# ...
# VLM SPATIAL UNDERSTANDING BENCHMARK — SINGLE MODEL
# ...
#   Config: config.yaml
#   Model:  InternVL3.5-1B
#   Dataset: nyu-visionx/CV-Bench
#   Samples: 1438
#   Type filter: 2d
#   GPU: Tesla T4
#   VRAM: 15.6 GB
#
# ...
# EVALUATING: InternVL3.5-1B
#   Path: OpenGVLab/InternVL3_5-1B-Instruct
#   Type: internvl
# ...
#
# ...
# LOADING CV-BENCH DATASET
# ...
# README.md: 6.14kB [00:00, 9.62MB/s]
# test_2d.parquet: 100% 185M/185M [00:05<00:00, 31.9MB/s]
# test_3d.parquet: 100% 220M/220M [00:05<00:00, 41.0MB/s]
# Generating test split: 100% 2638/2638 [00:01<00:00, 1994.38 examples/s]
# Filter: 100% 2638/2638 [00:12<00:00, 203.74 examples/s]
#   Filtered to type='2d': 1438 samples
#   Using 1438 samples for evaluation
#
#   Task distribution:
#     Count: 788
#     Relation: 650
#
#   Loading model...
# tokenizer_config.json: 11.5kB [00:00, 42.4MB/s]
# vocab.json: 3.38MB [00:00, 37.8MB/s]
# merges.txt: 1.67MB [00:00, 22.7MB/s]
# added_tokens.json: 100% 892/892 [00:00<00:00, 7.84MB/s]
# ...

# %%
# !python run_model.py --config config.yaml --model SpatialBot-3B
# Out:
# ...
# VLM SPATIAL UNDERSTANDING BENCHMARK — SINGLE MODEL
# ...
#   Config: config.yaml
#   Model:  SpatialBot-3B
#   Dataset: nyu-visionx/CV-Bench
#   Samples: 1438
#   Type filter: 2d
#   GPU: Tesla T4
#   VRAM: 15.6 GB
#
# ...
# EVALUATING: SpatialBot-3B
#   Path: RussRobin/SpatialBot-3B
#   Type: spatialbot
# ...
#
# ...
# LOADING CV-BENCH DATASET
# ...
#   Filtered to type='2d': 1438 samples
#   Using 1438 samples for evaluation
#
#   Task distribution:
#     Count: 788
#     Relation: 650
#
#   Loading model...
# config.json: 1.27kB [00:00, 7.47MB/s]
# configuration_bunny_phi.py: 11.6kB [00:00, 47.9MB/s]
# A new version of the following files was downloaded from https://huggingface.co/RussRobin/SpatialBot-3B:
# - configuration_bunny_phi.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# `torch_dtype` is deprecated! Use `dtype` instead!
# modeling_bunny_phi.py: 102kB [00:00, 48.9MB/s]
# ...

# %%
# !python run_model.py --config config.yaml --model "SmolVLM-500M-Instruct"
# Out:
# ...
# VLM SPATIAL UNDERSTANDING BENCHMARK — SINGLE MODEL
# ...
#   Config: config.yaml
#   Model:  SmolVLM-500M-Instruct
#   Dataset: nyu-visionx/CV-Bench
#   Samples: 1438
#   Type filter: 2d
#   GPU: Tesla T4
#   VRAM: 15.6 GB
#
# ...
# EVALUATING: SmolVLM-500M-Instruct
#   Path: HuggingFaceTB/SmolVLM-500M-Instruct
#   Type: smolvlm
# ...
#
# ...
# LOADING CV-BENCH DATASET
# ...
#   Filtered to type='2d': 1438 samples
#   Using 1438 samples for evaluation
#
#   Task distribution:
#     Count: 788
#     Relation: 650
#
#   Loading model...
# 2026-05-27 13:48:40.995556: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# ...

# %%
# !python run_model.py --config config.yaml --model "Qwen3-VL-8B-4bit"
# Out:
# ...
# VLM SPATIAL UNDERSTANDING BENCHMARK — SINGLE MODEL
# ...
#   Config: config.yaml
#   Model:  Qwen3-VL-8B-4bit
#   Dataset: nyu-visionx/CV-Bench
#   Samples: 1438
#   Type filter: 2d
#   GPU: Tesla T4
#   VRAM: 15.6 GB
#
# ...
# EVALUATING: Qwen3-VL-8B-4bit
#   Path: unsloth/Qwen3-VL-8B-Instruct-unsloth-bnb-4bit
#   Type: qwen
# ...
#
# ...
# LOADING CV-BENCH DATASET
# ...
#   Filtered to type='2d': 1438 samples
#   Using 1438 samples for evaluation
#
#   Task distribution:
#     Count: 788
#     Relation: 650
#
#   Loading model...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-05-27 14:00:21.934792: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ...

# %% [markdown]
# # Comparison of different models - VLM bench on CV-bench

# %%
# !python compare_models.py --config config.yaml
# Out:
# ...
# VLM BENCHMARK — MODEL COMPARISON
# ...
#   Results dir: results
#   Plots dir:   results/plots
#
#   Found results for 3 models: ['InternVL3.5-1B', 'Qwen3-VL-8B-4bit', 'SpatialBot-3B']
#
#   Summary saved to: results/benchmark_results.csv
#
# ...
# COMPARISON RESULTS
# ...
#
#                   mcq_accuracy      bleu    rouge1  rouge2    rougeL    meteor  bertscore_precision  bertscore_recall  bertscore_f1  avg_inference_time  total_inference_time  model_load_time
# Model
# InternVL3.5-1B        0.539638  0.000000  0.567455     0.0  0.567455  0.000000             0.595619          0.575694      0.583668            0.605139            870.189792        40.303663
# Qwen3-VL-8B-4bit      0.792072  0.131707  0.595735     0.0  0.595735  0.267733             0.730126          0.802455      0.762257            1.577412           2268.317984       198.841702
# ...

# %%
# !python test_spatialbot.py --image /content/image.jpg --question "How many table lamps are in the image? Select from the following choices. (A) 0 (B) 2 (C) 1 (D) 3"
# Out:
# Device: cuda:0
# Loading model: RussRobin/SpatialBot-3B
# 2026-05-27 03:57:38.994839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# Model loaded successfully.
#
# Loading image...
#
# Question: How many table lamps are in the image? Select from the following choices. (A) 0 (B) 2 (C) 1 (D) 3
# Response: C
